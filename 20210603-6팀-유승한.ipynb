# %%
def add(a,b): # a,b는 매개변수
    return a+b

print(add(3,4)) # 3,4는 인수
# Out:
# 7

# %%
# 일반적 함수
# 원의 넓이
def cricle_area(radius):
    area = 3.14*radius**2
    return area

cricle_area(5)
# Out:
# 78.5

# %%
#결과값이 없는 함수
def add(a,b):
    print()

# %%
alist = {
    '1팀':[25,39,29,27,22], 
    '2팀':[27, 24, 25, 29, 25], 
    '3팀':[25,26,25,23,23,28,27],
    '4팀':[21,23,30],
    '5팀':[26,41,24,31,21,34,27],
    '6팀':[21,29,27,25,25]}
age_li = []
for i,v in alist.items():
    print(f'{i}의 최저연령은{min(v)} 최고연령은 {max(v)}')
    age_li.extend(v)
    # print(age_li)
print(f'DT스쿨 최저연령은{min(age_li)} 최고연령은 {max(age_li)}')

# %%
# 우리팀 캐릭터 사전 만들기
# team_dic = {'닉네임':[취미, mbti, 좋아하는 여행지, 가고싶은 여행지, 좋아하는 일]}
team6_dic = {'한':['영화감상', 'ENTP', '경주', '두바이', '친구랑 술마시기'],'인':['넥플릭스 보기', 'ENFP', '제주도', '탄자니아', '맛있는 음식 먹기'],'빈':['핸드폰 보기', 'ESTP', '바다 앞 어디든', '코타키나발루', '드라이브'],'선':['게임', 'enfj', '부산', '가평', '수다떨기'],'솔':['독서','ISFP','동해','다낭','보드게임과 방탈출']}
import random
a = random.choice(team6_dic.keys()))
b_list = team6_dic[a]
print(f'{a}님을 소개합니다. {a}님의 취미는 {b_list[0]}입니다.')
print(f'MBTI는 {b_list[1]}이고, 좋아하는 여행지는 {b_list[2]}, 가고싶은 여행지는 {b_list[3]}!')
print(f'좋아하는 일은 {b_list[4]}입니다!')
print(f'사랑스러운 {a}님이시네요 :D')

# 캐릭터 사전 출력 함수로 만들고 random.choice()로 출력하게 수정해 주세요
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-7bd06325420a> in <module>()
#       3 team6_dic = {'한':['영화감상', 'ENTP', '경주', '두바이', '친구랑 술마시기'],'인':['넥플릭스 보기', 'ENFP', '제주도', '탄자니아', '맛있는 음식 먹기'],'빈':['핸드폰 보기', 'ESTP', '바다 앞 어디든', '코타키나발루', '드라이브'],'선':['게임', 'enfj', '부산', '가평', '수다떨기'],'솔':['독서','ISFP','동해','다낭','보드게임과 방탈출']}
#       4 import random
# ----> 5 a = random.choice(team6_dic.keys())
#       6 b_list = team6_dic[a]
#       7 print(f'{a}님을 소개합니다. {a}님의 취미는 {b_list[0]}입니다.')
#
# /usr/lib/python3.7/random.py in choice(self, seq)
#     260         except ValueError:
#     261             raise IndexError('Cannot choose from an empty sequence') from None
# --> 262         return seq[i]
#     263
#     264     def shuffle(self, x, random=None):
#
# TypeError: 'dict_keys' object is not subscriptable

# %% [markdown]
# # 문자열 나누기
# 문자열.split() 함수는 문자열을 일정한 규칙으로 잘라서 리스트로 만들어 주는 함수

# %%
text = '문자열 나누기'
sptext = text.split(sep=' ') # sep = seperate의 준말 및 구분자 입력
sptext
# Out:
# ['문자열', '나누기']

# %% [markdown]
# '구분자'.join(리스트) 함수는 리스트에 있는 요소 하나하나를 합쳐서 하나의 문자열로 바꾸어 반환

# %%
text2 = ' '.join(sptext)
text2
# Out:
# '문자열 나누기'

# %% [markdown]
# # 딕셔너리 값 가져오기
# 딕셔너리 값이 리스트, 딕셔너리 일 때

# %%
alist = {
    '키1':['값1', '값2'],
    '키2':['값3', '값4'],
    '키3':['값5', '값6']
    '키4':{'키':100]}}
print(list(alist['키1'])) # 딕셔너리 안에 있는 리스트 읽을 때
print(alist['키4'],['키']) # 딕셔너리 안에 있는 딕셔너리 읽을 때
# Out:
#   File "<ipython-input-24-60fd3c001c91>", line 5
#     '키4':{'키':100]}}
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 얼굴인식
# 얼굴 정보의 검출 및 추출 기술

# %% [markdown]
# # Open API
# Open API?
#
#     Open Application Programming Interface의 약어로서 누구나 사용할 수 있도록 공개된 API
#     Open API를 활용하기 위해서는 반드시 '서비스키'를 발급받아야 한다

# %% [markdown]
# ## 네이버 오픈 API
# - 오픈 API는 누구나 사용할 수 있도록 공개된 API
# - 하나의 웹 사이트에서 자신이 가진 기능을 이용할 수 있도록 공개한 프로그래밍 인터페이스
# - 개발자에게 응용 소프트웨어나 웹 서비스에 프로그래밍적인 권한을 제공

# %% [markdown]
# 네이버 오픈 API 목록 - https://developers.naver.com/docs/common/openapiguide/
#
# 이미지캡쳐 예시 코드 - https://developers.naver.com/docs/utils/captcha/examples/#python

# %% [markdown]
# ### 네이버 얼굴인식 API
# CLOVA Face Recognition
#
# 얼굴과 관련된 다양한 정보를 제공하는 얼굴 인식 API
#
# 얼굴을 인식하거나 얼굴 감지를 이용한 애플리케이션을 만들 때 유용한 API
#
# 유명인 얼굴 인식 및 정확한 얼굴 감지 기능

# %%
import os
import sys
import requests


# 등록된 client_id, client_secret 정보를 입력합니다.
client_id = "yBwPM0bgoQTE7MzqhxmM"
client_secret = "2HiUBFvSq_"

# 얼굴 사진을 통한 나이 추정을 위해서는 아래 url을 사용합니다. (face: 얼굴 분석, celebrity: 닮은 유명인 찾기)
url = "https://openapi.naver.com/v1/vision/face" 
url = "https://openapi.naver.com/v1/vision/celebrity" 

# 분석할 이미지의 파일명을 입력합니다./
files = {'image': open('/content/drive/MyDrive/2021 집들이.jpg', 'rb')}

# API 입력 설정
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# API 사용
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code

if (rescode==200):
    # 결과물 출력
    print (response.text)
else:
    print("Error Code:" + str(rescode))
# Out:
# {"info":{"size":{"width":1440,"height":1440},"faceCount":1},"faces":[{"celebrity":{"value":"문지윤","confidence":0.221356}}]}

# %%
import json

result = json.loads(response.text)
result
# Out:
# {'faces': [{'celebrity': {'confidence': 0.221356, 'value': '문지윤'}}],
#  'info': {'faceCount': 1, 'size': {'height': 1440, 'width': 1440}}}

# %%
#개인최종취합코드 -> 주말간 완성해봐야...
dic_6team = {"인":{"gender":"female","confidence1":0.999778,"age":"16~20","confidence2":0.849952,"celebrity":"김고은","confidence3":1.0},
                "솔":{"gender":"female","confidence1":0.999937,"age":"17~21","confidence2":1.0,"celebrity":"전효성","confidence3":0.225571},
                 "빈":{"gender":"female","confidence1":0.999694,"age":"18~22","confidence2":0.97328,"celebrity":"김태연","confidence3":1.0},
                  "선":{'gender':"female","confidence1": 0.999811,"age":"18~22","confidence2": 0.415346,"celebrity":"이지은","confidence3": 0.187127},
              "한":{'gender':"male","confidence1": 0.99991,"age":"23~27","confidence2": 0.947715,"celebrity":"문지윤","confidence3":0.22868}}

name = ['인', '솔', '빈', '선', '한']
age = []
for i in range(len(name)):
    b = name[i]
    c = dic_6team[b]["age"]
    age.append(c)
    for j in range(len(name)):
        d = int(age[j].split(sep='~')))
        spage.append(d)

#a = input()

#print(f'{a}님의 성별은 {dic_6team[a]["gender"]}이며 신뢰도는 {dic_6team[a]["confidence1"]}입니다.')
#print(f'{a}님의 나이 {dic_6team[a]["age".split('~')]}이며 신뢰도는 {dic_6team[a]["confidence2"]}입니다.')
#print(f'{a}님의 닮은꼴은 {dic_6team[a]["celebrity"]}이며 신뢰도는 {dic_6team[a]["confidence3"]}입니다.')

#print(f'6팀의 성별 신뢰도는 {dic_6team.keys("confidence1")/len(dic_6team)}입니다.')

print(age)
print(spage)
# Out:
#   File "<ipython-input-59-110abdbd88e0>", line 15
#     d = int(age[j].split(sep='~')))
#                                   ^
# SyntaxError: invalid syntax

# %%
# 윤혜선님이 짜신 코드 연예인 코드
team_cele = {
    '선':'이지은',
    '빈':'김태연',
    '인':'김고은',
    '한':'조여정',
    '솔':'전효성'
}
a=input()
b_list=team_cele[a]
print(f'{a}님의 닮은꼴 연예인은 {b_list}입니다.')

# %%
# [나이, 나이측정 정확도] - 이예빈님이 짜신 코드
data = [[18, 0.849952], [19, 1.0], [20, 0.97328], [20, 0.415346], [25, 0.947715]]
sum_age = 0
sum_con = 0
for i in range(len(data)):
    sum_age += data[i][0]
    sum_con += data[i][1]
print(f'''저희 6팀의 평균나이는 {sum_age/len(data)}입니다.
나이측정 정확도는 {sum_con/len(data)}입니다.''')

# %%
# 팀 최종 코드 합작
# 팀원 자랑 코드
team6_dic = {'한':['영화감상', 'ENTP', '경주', '두바이', '친구랑 술마시기'],'인':['넥플릭스 보기', 'ENFP', '제주도', '탄자니아', '맛있는 음식 먹기'],'빈':['핸드폰 보기', 'ESTP', '바다 앞 어디든', '코타키나발루', '드라이브'],'선':['게임', 'enfj', '부산', '가평', '수다떨기'],'솔':['독서','ISFP','동해','다낭','보드게임과 방탈출']}
a=input()
b_list = team6_dic[a]
print(f'{a}님을 소개합니다. {a}님의 취미는 {b_list[0]}입니다.')
print(f'MBTI는 {b_list[1]}이고, 좋아하는 여행지는 {b_list[2]}, 가고싶은 여행지는 {b_list[3]}!')
print(f'좋아하는 일은 {b_list[4]}입니다!')

# 팀원 닮은꼴 연예인 코드
team_cele = {
    '선':'이지은',
    '빈':'김태연',
    '인':'김고은',
    '한':'조여정',
    '솔':'전효성'
}
b_list=team_cele[a]
print(f'{a}님의 닮은꼴 연예인은 {b_list}입니다.')

# 팀 평균 나이와 정확도 코드
data = [[18, 0.849952], [19, 1.0], [20, 0.97328], [20, 0.415346], [25, 0.947715]]
sum_age = 0
sum_con = 0
for i in range(len(data)):
    sum_age += data[i][0]
    sum_con += data[i][1]
print(f'''저희 6팀의 평균나이는 {sum_age/len(data)}입니다.
나이측정 정확도는 {sum_con/len(data)}입니다.''')
# Out:
# 한
# 한님을 소개합니다. 한님의 취미는 영화감상입니다.
# MBTI는 ENTP이고, 좋아하는 여행지는 경주, 가고싶은 여행지는 두바이!
# 좋아하는 일은 친구랑 술마시기입니다!
# 한님의 닮은꼴 연예인은 조여정입니다.
# 저희 6팀의 평균나이는 20.4입니다.
# 나이측정 정확도는 0.8372586입니다.
