# %% [markdown]
# 팀과제] 우리 팀의 평균 나이는?
#
# 네이버 오픈 API - https://developers.naver.com/docs/common/openapiguide/
#
# 이미지캡쳐 예시 코드 - https://developers.naver.com/docs/utils/captcha/examples/#python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys
import requests


# 등록된 client_id, client_secret 정보를 입력합니다.
client_id = "yBwPM0bgoQTE7MzqhxmM"
client_secret = "2HiUBFvSq_"

# 얼굴 사진을 통한 나이 추정을 위해서는 아래 url을 사용합니다. (face: 얼굴 분석, celebrity: 닮은 유명인 찾기)
url = "https://openapi.naver.com/v1/vision/face/" 
#url = "https://openapi.naver.com/v1/vision/celebrity" 

# 분석할 이미지의 파일명을 입력합니다./
#files = {'image': open('/content/drive/MyDrive/KakaoTalk_20210603_144342342.jpg', 'rb')}

# API 입력 설정
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# API 사용
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code

if (rescode==200):
    # 결과물 출력
    print (response.text)
else:
    print("Error Code:" + str(rescode))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4c7f4ee6d948> in <module>()
#      19
#      20 # API 사용
# ---> 21 response = requests.post(url,  files=files, headers=headers)
#      22 rescode = response.status_code
#      23
#
# NameError: name 'files' is not defined

# %%
# json 형식을 사용하기 위하여 import 합니다.
import json

# loads 함수를 사용하여 json으로 변환합니다.
result = json.loads(response.text)
result

# %%
dict_team6 = {
    '선':['게임', 'ENTJ', '부산', '가평', '수다떨기'],
    '빈':['핸드폰 보기', 'ESTP', '바다 앞 어디든', '코타키나발루', '드라이브'],
    '인':['넥플릭스 보기', 'ENFP', '제주도', '탄자니아', '맛있는 음식 먹기'],
    '한':['영화감상', 'ENTP', '경주', '두바이', '친구랑 술마시기'],
    '솔':['독서','ISFP','동해','다낭','보드게임과 방탈출']
}
a=input('팀원:')
b_list=dict_team6[a]
print(f'{a}님을 소개합니다. {a}님의 취미는 {b_list[0]}입니다.')
print(f'mbti는 {b_list[1]}이고, 좋아하는 여행지는 {b_list[2]}, 가고싶은 여행지는 {b_list[3]}!')
print(f'좋아하는 일은 {b_list[-1]}입니다!')
print(f'사랑스러운 {a}님이시네요 :D')
# Out:
# 팀원:빈
# 빈님을 소개합니다. 빈님의 취미는 핸드폰 보기입니다.
# mbti는 ESTP이고, 좋아하는 여행지는 바다 앞 어디든, 가고싶은 여행지는 코타키나발루!
# 좋아하는 일은 드라이브입니다!
# 사랑스러운 빈님이시네요 :D
